# %% [markdown]
# # CSGO Weapons Classification using CNN

# %% [markdown]
# ## Loading libraries

# %%
import glob
import cv2
import os

# %%
import zipfile
import pathlib

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Importing Dataset

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
with zipfile.ZipFile('/content/drive/MyDrive/train_dir.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/datasets')
train_dir = pathlib.Path('/content/datasets/train_dir')
image_count = len(list(train_dir.glob('*/*')))
print(image_count)
# Out:
# 827

# %%
with zipfile.ZipFile('/content/drive/MyDrive/test_dir.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/datasets')
test_dir = pathlib.Path('/content/datasets/test_dir')
image_count = len(list(test_dir.glob('*/*')))
print(image_count)
# Out:
# 66

# %% [markdown]
# ## Preprocessing

# %%
batch_size = 3
img_height = 200
img_width = 200

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(
  train_dir,
  validation_split=0.2,
  subset="training",
  seed=42,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  )
# Out:
# Found 827 files belonging to 33 classes.
# Using 662 files for training.

# %%
val_data = tf.keras.preprocessing.image_dataset_from_directory(
  test_dir,
  validation_split=0.2,
  subset="validation",
  seed=42,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 66 files belonging to 33 classes.
# Using 13 files for validation.

# %%
class_names = val_data.class_names
print(class_names)
# Out:
# ['AK-47', 'AWP', 'Aug', 'CZ-75', 'Famas', 'Five_Seven', 'G3SG1', 'Galil-AR', 'Glock', 'M249', 'M4A1', 'M4A4', 'MAC-10', 'MP-5', 'MP-7', 'MP-9', 'Mag-7', 'Negev', 'Nova', 'P-2000', 'P-90', 'P250', 'Revolver', 'SG-553', 'Sawed-Off', 'Scar-20', 'Scout', 'Tec-9', 'UMP', 'USP', 'XM-1014', 'dual_pistol', 'pp']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_data.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ## Building CNN

# %%
model = tf.keras.Sequential([
    # rescaling layer (normalization of the images)
    layers.experimental.preprocessing.Rescaling(1./255),
    # convolution (filtering images with matrix) 
    # max pooling layers (reducing size of images)
    layers.Conv2D(128,4, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,4, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,4, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(16,4, activation='relu'),
    layers.MaxPooling2D(),
    # flatten layer (construction of a vector from the matrix)
    layers.Flatten(),
    # dense layer (neurons layers)
    layers.Dense(64, activation='relu'),
    layers.Dense(33, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'],)

# %% [markdown]
# ## Training CNN

# %%
model.fit( 
  train_data,
  validation_data=val_data,
  epochs=20,
  callbacks=[tensorboard_callback]
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 221/221 [==============================] - 5s 18ms/step - loss: 2.4159 - accuracy: 0.3686 - val_loss: 0.9743 - val_accuracy: 0.7692
# Epoch 2/20
# 221/221 [==============================] - 4s 17ms/step - loss: 0.2724 - accuracy: 0.9547 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 3/20
# 221/221 [==============================] - 4s 18ms/step - loss: 0.0635 - accuracy: 0.9864 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 4/20
# 221/221 [==============================] - 4s 18ms/step - loss: 0.0370 - accuracy: 0.9940 - val_loss: 7.0057e-06 - val_accuracy: 1.0000
# Epoch 5/20
# 221/221 [==============================] - 4s 18ms/step - loss: 1.8599e-04 - accuracy: 1.0000 - val_loss: 1.0637e-06 - val_accuracy: 1.0000
# Epoch 6/20
# 221/221 [==============================] - 4s 18ms/step - loss: 2.8652e-05 - accuracy: 1.0000 - val_loss: 3.3012e-07 - val_accuracy: 1.0000
# Epoch 7/20
# 221/221 [==============================] - 4s 18ms/step - loss: 1.4390e-05 - accuracy: 1.0000 - val_loss: 1.8340e-07 - val_accuracy: 1.0000
# Epoch 8/20
# 221/221 [==============================] - 4s 18ms/step - loss: 8.8878e-06 - accuracy: 1.0000 - val_loss: 1.1004e-07 - val_accuracy: 1.0000
# Epoch 9/20
# 221/221 [==============================] - 4s 18ms/step - loss: 6.1245e-06 - accuracy: 1.0000 - val_loss: 7.3360e-08 - val_accuracy: 1.0000
# Epoch 10/20
# 221/221 [==============================] - 4s 18ms/step - loss: 4.4936e-06 - accuracy: 1.0000 - val_loss: 4.5850e-08 - val_accuracy: 1.0000
# Epoch 11/20
# 221/221 [==============================] - 4s 18ms/step - loss: 3.3763e-06 - accuracy: 1.0000 - val_loss: 2.7510e-08 - val_accuracy: 1.0000
# Epoch 12/20
# 221/221 [==============================] - 4s 18ms/step - loss: 2.6402e-06 - accuracy: 1.0000 - val_loss: 2.7510e-08 - val_accuracy: 1.0000
# Epoch 13/20
# 221/221 [==============================] - 4s 18ms/step - loss: 2.0961e-06 - accuracy: 1.0000 - val_loss: 1.8340e-08 - val_accuracy: 1.0000
# Epoch 14/20
# 221/221 [==============================] - 4s 18ms/step - loss: 1.6957e-06 - accuracy: 1.0000 - val_loss: 9.1699e-09 - val_accuracy: 1.0000
# Epoch 15/20
# 221/221 [==============================] - 4s 18ms/step - loss: 1.3881e-06 - accuracy: 1.0000 - val_loss: 9.1699e-09 - val_accuracy: 1.0000
# Epoch 16/20
# 221/221 [==============================] - 4s 18ms/step - loss: 1.1490e-06 - accuracy: 1.0000 - val_loss: 9.1699e-09 - val_accuracy: 1.0000
# Epoch 17/20
# 221/221 [==============================] - 4s 18ms/step - loss: 9.5869e-07 - accuracy: 1.0000 - val_loss: 9.1699e-09 - val_accuracy: 1.0000
# Epoch 18/20
# 221/221 [==============================] - 4s 17ms/step - loss: 8.0599e-07 - accuracy: 1.0000 - val_loss: 9.1699e-09 - val_accuracy: 1.0000
# Epoch 19/20
# 221/221 [==============================] - 4s 17ms/step - loss: 6.8103e-07 - accuracy: 1.0000 - val_loss: 9.1699e-09 - val_accuracy: 1.0000
# Epoch 20/20
# 221/221 [==============================] - 4s 18ms/step - loss: 5.7965e-07 - accuracy: 1.0000 - val_loss: 9.1699e-09 - val_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 200, 200, 3)       0
#
#  conv2d_16 (Conv2D)          (None, 197, 197, 128)     6272
#
#  max_pooling2d_16 (MaxPoolin  (None, 98, 98, 128)      0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 95, 95, 64)        131136
#
#  max_pooling2d_17 (MaxPoolin  (None, 47, 47, 64)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 44, 44, 32)        32800
#
#  max_pooling2d_18 (MaxPoolin  (None, 22, 22, 32)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 19, 19, 16)        8208
#
#  max_pooling2d_19 (MaxPoolin  (None, 9, 9, 16)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 1296)              0
#
#  dense_8 (Dense)             (None, 64)                83008
#
#  dense_9 (Dense)             (None, 33)                2145
#
# =================================================================
# Total params: 263,569
# Trainable params: 263,569
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Making Predictions

# %%
from google.colab import files
file_to_predict = files.upload()
for file_ in file_to_predict:
    image_to_predict = cv2.imread(file_,cv2.IMREAD_COLOR)
    plt.imshow(cv2.cvtColor(image_to_predict, cv2.COLOR_BGR2RGB))
    plt.show()
    img_to_predict = np.expand_dims(cv2.resize(image_to_predict,(200,200)), axis=0)
    res = np.argmax(model.predict(img_to_predict))
    print('\nThe weapon in the image is a', class_names[res])
# Out:
#      <input type="file" id="files-3e0aec65-1f7d-47b5-9706-263e4fe60d74" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e0aec65-1f7d-47b5-9706-263e4fe60d74">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weapon_usp_silencer_sp_leaves_light_large.a71c8dc482fea4aaa1c6b5c115e370a7e134ddfd.png to weapon_usp_silencer_sp_leaves_light_large.a71c8dc482fea4aaa1c6b5c115e370a7e134ddfd (1).png
# The weapon in the image is a USP
